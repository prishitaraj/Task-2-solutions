# %%
import pandas as pd

# %%
df=pd.read_csv('2019_nCoV_20200121_20200127.csv')

# %%
df
# Out:
#     Province/State  Country/Region      Last Update  Confirmed  Suspected  \
# 0            Hubei  Mainland China  1/27/2020 20:30     2714.0        NaN
# 1         Zhejiang  Mainland China  1/27/2020 20:30      173.0        NaN
# 2            Henan  Mainland China  1/27/2020 20:30      168.0        NaN
# 3        Guangdong  Mainland China  1/27/2020 20:30      151.0        NaN
# 4        Chongqing  Mainland China  1/27/2020 20:30      132.0        NaN
# ..             ...             ...              ...        ...        ...
# 561   Heilongjiang  Mainland China        1/21/2020        NaN        1.0
# 562            NaN           Japan        1/21/2020        1.0        NaN
# 563            NaN        Thailand        1/21/2020        2.0        NaN
# 564            NaN     South Korea        1/21/2020        1.0        NaN
# 565     Washington   United States        1/21/2020        1.0        NaN
#
#      Recovered  Death
# 0         47.0  100.0
# 1          1.0    NaN
# ...

# %%
filt= (df.sort_values(by='Province/State'))

# %%
df.loc[filt]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-afd93b0f52ea> in <module>
# ----> 1 df.loc[filt]
#
# c:\users\prishita\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# c:\users\prishita\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1950
#    1951                 if hasattr(key, "ndim") and key.ndim > 1:
# -> 1952                     raise ValueError("Cannot index with multidimensional key")
#    1953
#    1954                 return self._getitem_iterable(key, axis=axis)
#
# ...
